# %%
import time

# %% [markdown]
# ### Run Dependencies

# %%
# %run ./utils.ipynb

# %% [markdown]
# ### Invoke Recommendation Engine

# %%
recommender = RecommendationEngine()

# %% [markdown]
# ### Run Recommendations

# %%
start = time.time()
recommender.execute_pipeline()
end = time.time()

#Subtract Start Time from The End Time
total_time = end - start
print("Number of seconds"+ str(total_time))
# Out:
# Running loop:  0 / 2194 customer profiles completed
# Running loop:  1 / 2194 customer profiles completed
# Running loop:  2 / 2194 customer profiles completed
# Running loop:  3 / 2194 customer profiles completed
# Running loop:  4 / 2194 customer profiles completed
# Running loop:  5 / 2194 customer profiles completed
# Running loop:  6 / 2194 customer profiles completed
# Running loop:  7 / 2194 customer profiles completed
# Running loop:  8 / 2194 customer profiles completed
# Running loop:  9 / 2194 customer profiles completed
# Running loop:  10 / 2194 customer profiles completed
# Running loop:  11 / 2194 customer profiles completed
# Running loop:  12 / 2194 customer profiles completed
# Running loop:  13 / 2194 customer profiles completed
# Running loop:  14 / 2194 customer profiles completed
# Running loop:  15 / 2194 customer profiles completed
# Running loop:  16 / 2194 customer profiles completed
# Running loop:  17 / 2194 customer profiles completed
# ...
